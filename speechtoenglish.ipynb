# %%
# !pip install git+https://github.com/openai/whisper.git 
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-q299cpa2
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-q299cpa2
#   Resolved https://github.com/openai/whisper.git to commit 7858aa9c08d98f75575035ecd6481f462d66ca27
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 71.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 51.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179424 sha256=107f4f362b4819a5c96ba53fa7f5e10625809141d4a93e292099b03c236ddd9d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e67e1qul/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# ...

# %%
import whisper

# %%
model=whisper.load_model('large')
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [00:49<00:00, 62.4MiB/s]

# %%
result=model.transcribe('Recording (2).wav',fp16=False,task='translate')

# %%
result['text']
# Out:
# ' I am very beautiful'

# %%
result=model.transcribe('Recording (3).m4a',fp16=False,task='translate')

# %%
result['text']
# Out:
# " Gandhiji's nature and qualities attracted all the students towards him."

# %%
result=model.transcribe('AUD-20230302-WA0028.m4a',fp16=False,task='translate')

# %%
result['text']
# Out:
# ' I am standing at the bus stop'
